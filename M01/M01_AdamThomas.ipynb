# %% [markdown]
# AS.430.271.81: M01 - Adam Thomas
# # M01 Homework
# Hello Mansour, looking forward to learning from you!
#
# Here is a screenshot of the web browser running this JupyterLab notebook:
# ![image.png](attachment:837e7f3b-bded-41d3-a930-de6056e1f146.png)
#
# Here is a screenshot of the docker log running on Amazon EC2:
# ![image.png](attachment:627f6a72-dd8a-4347-bf2f-56b6da7e40f9.png)
